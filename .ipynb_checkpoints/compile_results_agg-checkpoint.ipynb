# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Results_Warfarin_prob/compiled_results/unconstrained_agg.csv')

# %%
df[df['depth'] == 1]['solve_time'].mean()
# Out:
# 6.8418110550774465

# %%
df[df['depth'] == 2]['solve_time'].mean()
# Out:
# 244.0211661031511

# %%
sns.boxplot(data=df, x='method', y='solve_time', hue='depth')
plt.show()

# %%
sns.boxplot(data=df, x='method', y='gap', hue='depth')
plt.show()

# %%
for r in ['0.33', 'r0.06', 'r0.11']:
    subset = df[df['randomization'] == r]
    sns.boxplot(data=subset, x='method', y='best_found_test', hue='depth')
    plt.title(r)
    plt.show()

# %%
sns.boxplot(data=df, x='method', y='best_found_test', hue='depth')
plt.show()
